# %%
import os

import torchvision
from torchvision.transforms import v2
import torch
import torch.nn as nn
from torch.utils.data.dataloader import DataLoader

EXAMPLES_FOR_PLOT = 5 # should be less than batch

LATENT_SIZE = 64
BATCH_SIZE = 64
EPOCHS = 100
DATA_PATH = "data/celeba"
DEVICE = "cpu"

if torch.cuda.is_available():
    DEVICE = "cuda"

os.makedirs(DATA_PATH, exist_ok=True)
transform = v2.Compose([
    v2.ToImage(),
    v2.ToDtype(torch.float32, scale=True),
    v2.Lambda(lambda t: t/255) # TODO normal scaling
])
train_data = torchvision.datasets.CelebA(DATA_PATH, download=False, transform=transform, split="train")
test_data = torchvision.datasets.CelebA(DATA_PATH, download=False, transform=transform, split="test")

train_dataloader = DataLoader(train_data, BATCH_SIZE, shuffle=True)
test_dataloader = DataLoader(test_data, BATCH_SIZE, shuffle=False)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 26
#      20 os.makedirs(DATA_PATH, exist_ok=True)
#      21 transform = v2.Compose([
#      22     v2.ToImage(),
#      23     v2.ToDtype(torch.float32, scale=True),
#      24     v2.Lambda(lambda t: t/255) # TODO normal scaling
#      25 ])
# ---> 26 train_data = torchvision.datasets.CelebA(DATA_PATH, download=False, transform=transform, split="train")
#      27 test_data = torchvision.datasets.CelebA(DATA_PATH, download=False, transform=transform, split="test")
#      29 train_dataloader = DataLoader(train_data, BATCH_SIZE, shuffle=True)
#
# File ~/conda/envs/kaggle-env/lib/python3.14/site-packages/torchvision/datasets/celeba.py:88, in CelebA.__init__(self, root, split, target_type, transform, target_transform, download)
#      85     self.download()
#      87 if not self._check_integrity():
# ...
